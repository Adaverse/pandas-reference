# %%
import math

for i in range (20):
    try:
        input_n = input("Input a number:")
        if input_n == "quit":
            break
        r = math.log(float(input_n))
        print (r)
    except ValueError:
        print ("input error: value must > 0")
        break
    except Exception:
        print ("Unknown error")
# Out:
# Input a number:jhghjg
# input error: value must > 0

# %%
class FirstError (ValueError):
    pass

# %%
l_1 = ["Welcome", "to", "Python"]
while True:
    input_l = input()
    if input_l not in l_1:
        raise FirstError("Invalid input")
# Out:
# Welcome
# Python
# Hello
# ---------------------------------------------------------------------------
# FirstError                                Traceback (most recent call last)
# <ipython-input-3-76b5cb1b8a9c> in <module>()
#       3     input_l = input()
#       4     if input_l not in l_1:
# ----> 5         raise FirstError("Invalid input")
#
# FirstError: Invalid input

# %%
try:
    print("try")
finally:
    print("finally")
# Out:
# try
# finally

# %%
try:
    1/0
finally:
    print("this function")
# Out:
# this function
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-52e63a69ca2e> in <module>()
#       1 try:
# ----> 2     1/0
#       3 finally:
#       4     print("this function")
#
# ZeroDivisionError: division by zero

# %%
try:
    1/0
except:
    print("this is except")
finally:
    print("this function")
# Out:
# this is except
# this function
