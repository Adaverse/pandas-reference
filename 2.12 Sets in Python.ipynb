# %%
l_1 = [222,333,444,333]
l_1 = set(l_1)

# %%
l_1
# Out:
# {222, 333, 444}

# %%
s_1 = {1,2,3,4,4,5,5,6,6}
type(s_1)
# Out:
# set

# %%
s_1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a = {1,2,3,4,5}
b = {2,3,4,5,6}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a.intersection(b)
# Out:
# {2, 3, 4, 5}

# %%
b.difference(a)
# Out:
# {6}

# %%
a - b
# Out:
# {1}

# %%
b - a
# Out:
# {6}

# %%
c = {1,2,3,4,5}
d = {1,2,3}
d.issubset(c)
# Out:
# True

# %%
c.issubset(d)
# Out:
# False

# %%
d <= c
# Out:
# True

# %%
d > c
# Out:
# False

# %%
e = {1,2,3,4}
e.add(5)
e
# Out:
# {1, 2, 3, 4, 5}

# %%
e.add(5)
e
# Out:
# {1, 2, 3, 4, 5}

# %%
e.update([5,6,7])
e
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
e.remove(1)
e
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
e.pop()
e
# Out:
# {3, 4, 5, 6, 7}

# %%
s = {1,2,'1'}

# %%
s
# Out:
# {1, '1', 2}

# %%
type(s)
# Out:
# set
