# %%
a = [1,2,[3,4]]
a
# Out:
# [1, 2, [3, 4]]

# %%
a[2]
# Out:
# [3, 4]

# %%
a[2] [0]
# Out:
# 3

# %%
a[0] [0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ac3a4b7f8041> in <module>()
# ----> 1 a[0] [0]
#
# TypeError: 'int' object is not subscriptable

# %%
b = [51, "pear","apple","apple","apple","apple","pear","pear","pear",]
b.count(b[1])
# Out:
# 4

# %%
b.append("orange")

# %%
b
# Out:
# [51,
#  'pear',
#  'apple',
#  'apple',
#  'apple',
#  'apple',
#  'pear',
#  'pear',
#  'pear',
#  'orange']

# %%
b.append(["banana","melon"])
b
# Out:
# [51,
#  'pear',
#  'apple',
#  'apple',
#  'apple',
#  'apple',
#  'pear',
#  'pear',
#  'pear',
#  'orange',
#  ['banana', 'melon']]

# %%
b.insert(3,"banana")
b
# Out:
# [51,
#  'pear',
#  'apple',
#  'banana',
#  'apple',
#  'apple',
#  'apple',
#  'pear',
#  'pear',
#  'pear',
#  'orange',
#  ['banana', 'melon']]

# %%
b.remove(b[0])
b
# Out:
# ['banana',
#  'apple',
#  'apple',
#  'apple',
#  'pear',
#  'pear',
#  'pear',
#  'orange',
#  ['banana', 'melon']]

# %%
b.pop(1)
# Out:
# 'pear'

# %%
b
# Out:
# [51,
#  'banana',
#  'apple',
#  'apple',
#  'apple',
#  'pear',
#  'pear',
#  'pear',
#  'orange',
#  ['banana', 'melon']]

# %%
c = [1,4,5,6,7,3,2,6]
d = sorted(c)

# %%
c
# Out:
# [1, 4, 5, 6, 7, 3, 2, 6]

# %%
d
# Out:
# [1, 2, 3, 4, 5, 6, 6, 7]

# %%
e = ["Python", "Hello"]
e.reverse()

# %%
e
# Out:
# ['Hello', 'Python']

# %%
a = [1,2,3,4]
b = [1,2]

# %%
a.remove(1)
