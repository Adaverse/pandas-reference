# %%
d_4 = {}
d1 = {"apple":10, "pear":17}
d2 = {"potatoes":5, "tomatoes":11}
d_4["d1"]=d1
d_4["d2"]=d2
d_4
# Out:
# {'d1': {'apple': 10, 'pear': 17}, 'd2': {'potatoes': 5, 'tomatoes': 11}}

# %%
d1["apple"] +=1
d1
# Out:
# {'apple': 11, 'pear': 17}

# %%
d1.get("apple")
# Out:
# 11

# %%
d1["banana"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-5c3f5eeaea05> in <module>()
# ----> 1 d1["banana"]
#
# KeyError: 'banana'

# %%
d1.get("banana", "not found")
# Out:
# 'not found'

# %%
d1.pop("apple")
# Out:
# 11

# %%
d1
# Out:
# {'pear': 17}

# %%
del d1["pear"]
d1
# Out:
# {}

# %%
d_5 = {"apple":3, "pear":10}
d_6 = {"apple": 12, "banana":13}
d_5.update(d_6)
d_5
# Out:
# {'apple': 12, 'banana': 13, 'pear': 10}

# %%
"banana" in d_5
# Out:
# True

# %%
"tomatoes" in d_5
# Out:
# False

# %%
d_5.keys()
# Out:
# dict_keys(['apple', 'pear', 'banana'])

# %%
d_5.values()
# Out:
# dict_values([12, 10, 13])

# %%
d_5.items()
# Out:
# dict_items([('apple', 12), ('pear', 10), ('banana', 13)])

# %%
type(d_4)
# Out:
# dict
