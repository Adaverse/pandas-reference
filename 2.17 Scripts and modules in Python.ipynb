# %%
# %%writefile test.py

v_1 = 10
def v_add (v_list):
    c=0
    for i in range(len(v_list)):
        c += v_list[i]
    return c
l_1 = [1,2,3,4]
print (v_add(l_1))
# Out:
# Writing test.py

# %%
# %run test.py
# Out:
# 10

# %%
import test
# Out:
# 10

# %%
test
# Out:
# <module 'test' from '/Users/akashsharma/Downloads/udemy_data_science/test.py'>

# %%
print (test.v_1)
# Out:
# 10

# %%
test.v_1 = 30
test.v_1
# Out:
# 30

# %%
l_2 = [20,30,40]
test.v_add(l_2)
# Out:
# 90

# %%
import test as ts

# %%
ts.v_1
# Out:
# 30

# %%
ts.v_add(l_2)
# Out:
# 90

# %%
from test import v_1, v_add

# %%
v_1
# Out:
# 30

# %%
v_add(l_2)
# Out:
# 90

# %%
from test import *

# %%
import os

# %%
os.path.abspath(".")
# Out:
# '/Users/akashsharma/Downloads/udemy_data_science'

# %%
os.remove("test.py")
